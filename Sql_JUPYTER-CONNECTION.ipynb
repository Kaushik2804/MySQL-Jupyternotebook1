# %%
import pandas as pd
from sqlalchemy import create_engine
import pymysql

# %%
user = 'root'
password = 'root'
host = 'localhost'
db_name = 'first_db'
port = 3306

# %%
sqlEngine = create_engine(f'mysql+pymysql://{user}:{password}@{host}/{db_name}', pool_recycle=port)
dbConnection = sqlEngine.connect()

# %%
sql_query = "select * from first_db.formatted_microsoft"

# %%
df = pd.read_sql(sql_query, dbConnection)

# %%
df.head()
# Out:
#                 Event Time deviceVendor      deviceProduct  \
# 0  2024/02/11 17:32:34 IST    Microsoft  Microsoft Windows
# 1  2024/02/11 17:32:34 IST    Microsoft  Microsoft Windows
# 2  2024/02/11 17:32:34 IST    Microsoft  Microsoft Windows
# 3  2024/02/11 17:32:34 IST    Microsoft  Microsoft Windows
# 4  2024/02/11 17:32:34 IST    Microsoft  Microsoft Windows
#
#          deviceVersion                                       name  \
# 0  Windows Server 2019  Special privileges assigned to new logon.
# 1  Windows Server 2019                 An account was logged off.
# 2  Windows Server 2019  Special privileges assigned to new logon.
# 3  Windows Server 2019     An account was successfully logged on.
# 4  Windows Server 2019     An account was successfully logged on.
#
#               Receipt Time        deviceReceiptTime  deviceAddress  \
# 0  2024/02/11 17:32:42 IST  2024/02/11 17:30:58 IST  192.168.1.246
# 1  2024/02/11 17:32:42 IST  2024/02/11 17:30:58 IST  192.168.1.246
# 2  2024/02/11 17:32:42 IST  2024/02/11 17:31:49 IST  192.168.1.246
# 3  2024/02/11 17:32:42 IST  2024/02/11 17:31:49 IST  192.168.1.246
# 4  2024/02/11 17:32:42 IST  2024/02/11 17:31:49 IST  192.168.1.246
#
#   deviceSeverity       deviceHostName  ...  \
# 0  Audit_success  sky.rahinfotech.com  ...
# 1  Audit_success  sky.rahinfotech.com  ...
# 2  Audit_success  sky.rahinfotech.com  ...
# 3  Audit_success  sky.rahinfotech.com  ...
# 4  Audit_success  sky.rahinfotech.com  ...
#
#                                              message destinationProcessName  \
# 0                                                 NA                     NA
# 1  Network: A user or computer logged on to this ...                     NA
# 2                                                 NA                     NA
# 3  Network: A user or computer logged on to this ...
# 4  Network: A user or computer logged on to this ...
#
#         sourceHostName sourceUserName  sourcePort  sourceAddress reason  \
# 0                   NA             NA          NA             NA     NA
# 1                   NA             NA          NA             NA     NA
# 2                   NA             NA          NA             NA     NA
# 3  sky.rahinfotech.com             NA     53725.0  192.168.1.246     NA
# 4  sky.rahinfotech.com             NA     53723.0  192.168.1.246     NA
#
#   fileName deviceProcessName fileType
# 0       NA                NA       NA
# 1       NA                NA       NA
# 2       NA                NA       NA
# 3   %%1842          Kerberos   %%1843
# 4   %%1842          Kerberos   %%1843
#
# [5 rows x 31 columns]
